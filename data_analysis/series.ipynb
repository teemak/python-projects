# %%
import pandas as pd

# %%
ice_cream = ["Chocolate", "Vanilla", "Strawberry", "Pistachio"]
pd.Series(ice_cream)
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3     Pistachio
# dtype: object

# %%
lottery = [4,8,15,16,23,42]
pd.Series(lottery)
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %%
registration = [False, True, True, False, False]
pd.Series(registration)
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
webster = {"dog": "my pet", "banana": "fruit", "Cyan": "color"}
pd.Series(webster)
# Out:
# Cyan       color
# banana     fruit
# dog       my pet
# dtype: object

# %%
about_me = ["Smart", "Handsome", "Charming", "Brilliant", "Humble"]
s = pd.Series(about_me)
s
# Out:
# 0        Smart
# 1     Handsome
# 2     Charming
# 3    Brilliant
# 4       Humble
# dtype: object

# %%
s.values
# Out:
# array(['Smart', 'Handsome', 'Charming', 'Brilliant', 'Humble'], dtype=object)

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.dtype
# Out:
# dtype('O')

# %%
#dytpe('O') = object => pandas.string

# %%
prices = [2.98, 4.45, 1.35]
s = pd.Series(prices)

# %%
s
# Out:
# 0    2.98
# 1    4.45
# 2    1.35
# dtype: float64

# %%
s.sum()
# Out:
# 8.78

# %%
s.product()
# Out:
# 17.902350000000002

# %%
s.mean()
# Out:
# 2.9266666666666663

# %%
fruits = ["apple", "plum", "orange", "grape", "blueberry"]
weekdays = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]

pd.Series(fruits, weekdays)
# Out:
# Monday           apple
# Tuesday           plum
# Wednesday       orange
# Thursday         grape
# Friday       blueberry
# dtype: object

# %%
fruits = ["apple", "plum", "orange", "grape", "blueberry", "Pineapple"]
weekdays = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]
pd.Series(fruits, weekdays)
# Out:
# Monday           apple
# Tuesday           plum
# Wednesday       orange
# Thursday         grape
# Friday       blueberry
# Saturday     Pineapple
# dtype: object

# %%
pokemon = pd.read_csv("pokemon.csv", usecols = ["Pokemon"], squeeze = True)
pokemon
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28        Nidoran
# 29       Nidorina
#           ...
# 691     Clauncher
# 692     Clawitzer
# 693    Helioptile
# 694     Heliolisk
# 695        Tyrunt
# 696     Tyrantrum
# 697        Amaura
# 698       Aurorus
# 699       Sylveon
# 700      Hawlucha
# 701       Dedenne
# 702       Carbink
# 703         Goomy
# 704       Sliggoo
# 705        Goodra
# 706        Klefki
# 707      Phantump
# 708     Trevenant
# 709     Pumpkaboo
# ...

# %%
prices = pd.read_csv("google_stock_price.csv", squeeze = True)
prices
# Out:
# 0        50.12
# 1        54.10
# 2        54.65
# 3        52.38
# 4        52.95
# 5        53.90
# 6        53.02
# 7        50.95
# 8        51.13
# 9        50.07
# 10       50.70
# 11       49.95
# 12       50.74
# 13       51.10
# 14       51.10
# 15       52.61
# 16       53.70
# 17       55.69
# 18       55.94
# 19       56.93
# 20       58.69
# 21       59.62
# 22       58.86
# 23       59.13
# 24       60.35
# 25       59.86
# 26       59.07
# 27       63.37
# 28       65.47
# 29       64.74
#          ...
# 2982    675.22
# 2983    668.26
# 2984    680.04
# 2985    684.11
# 2986    692.10
# 2987    699.21
# 2988    694.49
# 2989    697.77
# 2990    695.36
# 2991    705.63
# 2992    715.09
# 2993    720.64
# 2994    716.98
# 2995    720.95
# 2996    719.85
# 2997    733.78
# 2998    736.96
# 2999    741.19
# 3000    738.63
# 3001    742.74
# 3002    739.77
# 3003    738.42
# 3004    741.77
# 3005    745.91
# 3006    768.79
# 3007    772.88
# 3008    771.07
# ...

# %%
pokemon.head(10)
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# 5     Charizard
# 6      Squirtle
# 7     Wartortle
# 8     Blastoise
# 9      Caterpie
# Name: Pokemon, dtype: object

# %%
prices.tail()
# Out:
# 3007    772.88
# 3008    771.07
# 3009    773.18
# 3010    771.61
# 3011    782.22
# Name: Stock Price, dtype: float64

# %%
prices.tail(10)
# Out:
# 3002    739.77
# 3003    738.42
# 3004    741.77
# 3005    745.91
# 3006    768.79
# 3007    772.88
# 3008    771.07
# 3009    773.18
# 3010    771.61
# 3011    782.22
# Name: Stock Price, dtype: float64

# %%
len(pokemon)
# Out:
# 721

# %%
type(pokemon)
# Out:
# pandas.core.series.Series

# %%
dir(pokemon)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
sorted(pokemon)
# Out:
# ['Abomasnow',
#  'Abra',
#  'Absol',
#  'Accelgor',
#  'Aegislash',
#  'Aerodactyl',
#  'Aggron',
#  'Aipom',
#  'Alakazam',
#  'Alomomola',
#  'Altaria',
#  'Amaura',
#  'Ambipom',
#  'Amoonguss',
#  'Ampharos',
#  'Anorith',
#  'Arbok',
#  'Arcanine',
#  'Arceus',
#  'Archen',
#  'Archeops',
#  'Ariados',
#  'Armaldo',
#  'Aromatisse',
#  'Aron',
#  'Articuno',
#  'Audino',
#  'Aurorus',
#  'Avalugg',
#  'Axew',
#  'Azelf',
#  'Azumarill',
#  'Azurill',
#  'Bagon',
#  'Baltoy',
#  'Banette',
#  'Barbaracle',
#  'Barboach',
#  'Basculin',
#  'Bastiodon',
#  'Bayleef',
#  'Beartic',
#  'Beautifly',
#  'Beedrill',
#  'Beheeyem',
#  'Beldum',
#  'Bellossom',
#  'Bellsprout',
#  'Bergmite',
#  'Bibarel',
#  'Bidoof',
#  'Binacle',
#  'Bisharp',
#  'Blastoise',
#  'Blaziken',
#  'Blissey',
#  'Blitzle',
#  'Boldore',
#  'Bonsly',
#  'Bouffalant',
#  'Braixen',
#  'Braviary',
#  'Breloom',
#  'Bronzong',
#  'Bronzor',
#  'Budew',
#  'Buizel',
#  'Bulbasaur',
#  'Buneary',
#  'Bunnelby',
# ...

# %%
list(pokemon)
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Venusaur',
#  'Charmander',
#  'Charmeleon',
#  'Charizard',
#  'Squirtle',
#  'Wartortle',
#  'Blastoise',
#  'Caterpie',
#  'Metapod',
#  'Butterfree',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Spearow',
#  'Fearow',
#  'Ekans',
#  'Arbok',
#  'Pikachu',
#  'Raichu',
#  'Sandshrew',
#  'Sandslash',
#  'Nidoran',
#  'Nidorina',
#  'Nidoqueen',
#  'Nidoran♂',
#  'Nidorino',
#  'Nidoking',
#  'Clefairy',
#  'Clefable',
#  'Vulpix',
#  'Ninetales',
#  'Jigglypuff',
#  'Wigglytuff',
#  'Zubat',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Vileplume',
#  'Paras',
#  'Parasect',
#  'Venonat',
#  'Venomoth',
#  'Diglett',
#  'Dugtrio',
#  'Meowth',
#  'Persian',
#  'Psyduck',
#  'Golduck',
#  'Mankey',
#  'Primeape',
#  'Growlithe',
#  'Arcanine',
#  'Poliwag',
#  'Poliwhirl',
#  'Poliwrath',
#  'Abra',
#  'Kadabra',
#  'Alakazam',
#  'Machop',
#  'Machoke',
#  'Machamp',
# ...

# %%
dict(pokemon)
# Out:
# {0: 'Bulbasaur',
#  1: 'Ivysaur',
#  2: 'Venusaur',
#  3: 'Charmander',
#  4: 'Charmeleon',
#  5: 'Charizard',
#  6: 'Squirtle',
#  7: 'Wartortle',
#  8: 'Blastoise',
#  9: 'Caterpie',
#  10: 'Metapod',
#  11: 'Butterfree',
#  12: 'Weedle',
#  13: 'Kakuna',
#  14: 'Beedrill',
#  15: 'Pidgey',
#  16: 'Pidgeotto',
#  17: 'Pidgeot',
#  18: 'Rattata',
#  19: 'Raticate',
#  20: 'Spearow',
#  21: 'Fearow',
#  22: 'Ekans',
#  23: 'Arbok',
#  24: 'Pikachu',
#  25: 'Raichu',
#  26: 'Sandshrew',
#  27: 'Sandslash',
#  28: 'Nidoran',
#  29: 'Nidorina',
#  30: 'Nidoqueen',
#  31: 'Nidoran♂',
#  32: 'Nidorino',
#  33: 'Nidoking',
#  34: 'Clefairy',
#  35: 'Clefable',
#  36: 'Vulpix',
#  37: 'Ninetales',
#  38: 'Jigglypuff',
#  39: 'Wigglytuff',
#  40: 'Zubat',
#  41: 'Golbat',
#  42: 'Oddish',
#  43: 'Gloom',
#  44: 'Vileplume',
#  45: 'Paras',
#  46: 'Parasect',
#  47: 'Venonat',
#  48: 'Venomoth',
#  49: 'Diglett',
#  50: 'Dugtrio',
#  51: 'Meowth',
#  52: 'Persian',
#  53: 'Psyduck',
# ...

# %%
max(pokemon)
# Out:
# 'Zygarde'

# %%
min(pokemon)
# Out:
# 'Abomasnow'

# %%
pokemon.values
# Out:
# array(['Bulbasaur', 'Ivysaur', 'Venusaur', 'Charmander', 'Charmeleon',
#        'Charizard', 'Squirtle', 'Wartortle', 'Blastoise', 'Caterpie',
#        'Metapod', 'Butterfree', 'Weedle', 'Kakuna', 'Beedrill', 'Pidgey',
#        'Pidgeotto', 'Pidgeot', 'Rattata', 'Raticate', 'Spearow', 'Fearow',
#        'Ekans', 'Arbok', 'Pikachu', 'Raichu', 'Sandshrew', 'Sandslash',
#        'Nidoran', 'Nidorina', 'Nidoqueen', 'Nidoran♂', 'Nidorino',
#        'Nidoking', 'Clefairy', 'Clefable', 'Vulpix', 'Ninetales',
#        'Jigglypuff', 'Wigglytuff', 'Zubat', 'Golbat', 'Oddish', 'Gloom',
#        'Vileplume', 'Paras', 'Parasect', 'Venonat', 'Venomoth', 'Diglett',
#        'Dugtrio', 'Meowth', 'Persian', 'Psyduck', 'Golduck', 'Mankey',
#        'Primeape', 'Growlithe', 'Arcanine', 'Poliwag', 'Poliwhirl',
#        'Poliwrath', 'Abra', 'Kadabra', 'Alakazam', 'Machop', 'Machoke',
#        'Machamp', 'Bellsprout', 'Weepinbell', 'Victreebel', 'Tentacool',
# ...

# %%
pokemon.index
# Out:
# RangeIndex(start=0, stop=721, step=1)

# %%
pokemon.dtype
# Out:
# dtype('O')

# %%
pokemon.is_unique
# Out:
# True

# %%
prices.is_unique
# Out:
# False

# %%
pokemon.shape
# Out:
# (721,)

# %%
pokemon.size
# Out:
# 721

# %%
pokemon.name
# Out:
# 'Pokemon'

# %%
prices.name
# Out:
# 'Stock Price'

# %%
pokemon.name = "Tee's Pokemon"

# %%
pokemon.head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Tee's Pokemon, dtype: object

# %%
pokemon.sort_values()
# Out:
# 459     Abomasnow
# 62           Abra
# 358         Absol
# 616      Accelgor
# 680     Aegislash
# 141    Aerodactyl
# 305        Aggron
# 189         Aipom
# 64       Alakazam
# 593     Alomomola
# 333       Altaria
# 697        Amaura
# 423       Ambipom
# 590     Amoonguss
# 180      Ampharos
# 346       Anorith
# 23          Arbok
# 58       Arcanine
# 492        Arceus
# 565        Archen
# 566      Archeops
# 167       Ariados
# 347       Armaldo
# 682    Aromatisse
# 303          Aron
# 143      Articuno
# 530        Audino
# 698       Aurorus
# 712       Avalugg
# 609          Axew
#           ...
# 69     Weepinbell
# 109       Weezing
# 546    Whimsicott
# 543    Whirlipede
# 339      Whiscash
# 292       Whismur
# 39     Wigglytuff
# 277       Wingull
# 201     Wobbuffet
# 526        Woobat
# 193        Wooper
# 412      Wormadam
# 264       Wurmple
# 359        Wynaut
# 177          Xatu
# 715       Xerneas
# 561        Yamask
# 192         Yanma
# 468       Yanmega
# ...

# %%
pokemon.sort_values(ascending = False).head()
# Out:
# 717     Zygarde
# 633    Zweilous
# 40        Zubat
# 569       Zorua
# 570     Zoroark
# Name: Tee's Pokemon, dtype: object

# %%
prices.sort_values(ascending = False)
# Out:
# 3011    782.22
# 2859    776.60
# 3009    773.18
# 3007    772.88
# 3010    771.61
# 3008    771.07
# 2860    771.00
# 3006    768.79
# 2840    767.04
# 2843    766.81
# 2934    766.61
# 2882    764.65
# 2844    763.25
# 2858    762.51
# 2841    762.38
# 2845    762.37
# 2937    759.14
# 2933    759.00
# 2861    758.88
# 2851    758.09
# 2834    756.60
# 2835    755.98
# 2935    753.93
# 2932    753.20
# 2936    752.67
# 2842    752.54
# 2881    752.00
# 2931    751.72
# 2846    751.61
# 2921    750.53
#          ...
# 28       65.47
# 29       64.74
# 27       63.37
# 24       60.35
# 25       59.86
# 21       59.62
# 23       59.13
# 26       59.07
# 22       58.86
# 20       58.69
# 19       56.93
# 18       55.94
# 17       55.69
# 2        54.65
# 1        54.10
# 5        53.90
# 16       53.70
# 6        53.02
# 4        52.95
# 15       52.61
# 3        52.38
# 8        51.13
# 13       51.10
# 14       51.10
# 7        50.95
# 12       50.74
# 10       50.70
# ...

# %%
prices.head()
# Out:
# 0    50.12
# 1    54.10
# 2    54.65
# 3    52.38
# 4    52.95
# Name: Stock Price, dtype: float64

# %%
prices = prices.sort_values()

# %%
prices
# Out:
# 11       49.95
# 9        50.07
# 0        50.12
# 10       50.70
# 12       50.74
# 7        50.95
# 14       51.10
# 13       51.10
# 8        51.13
# 3        52.38
# 15       52.61
# 4        52.95
# 6        53.02
# 16       53.70
# 5        53.90
# 1        54.10
# 2        54.65
# 17       55.69
# 18       55.94
# 19       56.93
# 20       58.69
# 22       58.86
# 26       59.07
# 23       59.13
# 21       59.62
# 25       59.86
# 24       60.35
# 27       63.37
# 29       64.74
# 28       65.47
#          ...
# 2921    750.53
# 2846    751.61
# 2931    751.72
# 2881    752.00
# 2842    752.54
# 2936    752.67
# 2932    753.20
# 2935    753.93
# 2835    755.98
# 2834    756.60
# 2851    758.09
# 2861    758.88
# 2933    759.00
# 2937    759.14
# 2845    762.37
# 2841    762.38
# 2858    762.51
# 2844    763.25
# 2882    764.65
# 2934    766.61
# 2843    766.81
# 2840    767.04
# 3006    768.79
# 2860    771.00
# 3008    771.07
# 3010    771.61
# 3007    772.88
# ...

# %%
pokemon.sort_values(ascending = False, inplace = True)

# %%
pokemon.head()
# Out:
# 717     Zygarde
# 633    Zweilous
# 40        Zubat
# 569       Zorua
# 570     Zoroark
# Name: Tee's Pokemon, dtype: object

# %%
pokemon.sort_index()
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28        Nidoran
# 29       Nidorina
#           ...
# 691     Clauncher
# 692     Clawitzer
# 693    Helioptile
# 694     Heliolisk
# 695        Tyrunt
# 696     Tyrantrum
# 697        Amaura
# 698       Aurorus
# 699       Sylveon
# 700      Hawlucha
# 701       Dedenne
# 702       Carbink
# 703         Goomy
# 704       Sliggoo
# 705        Goodra
# 706        Klefki
# 707      Phantump
# 708     Trevenant
# 709     Pumpkaboo
# ...

# %%
"Pikachu" in pokemon.values
# Out:
# True

# %%
pokemon[500]
# Out:
# 'Oshawott'

# %%
pokemon[[100,200]]
pokemon[50:100]
# Out:
# 415     Vespiquen
# 2        Venusaur
# 47        Venonat
# 48       Venomoth
# 542      Venipede
# 133      Vaporeon
# 583     Vanilluxe
# 581     Vanillite
# 582     Vanillish
# 479          Uxie
# 216      Ursaring
# 200         Unown
# 520      Unfezant
# 196       Umbreon
# 695        Tyrunt
# 235       Tyrogue
# 696     Tyrantrum
# 247     Tyranitar
# 156    Typhlosion
# 601        Tynamo
# 534       Tympole
# 386       Turtwig
# 567      Trubbish
# 356       Tropius
# 708     Trevenant
# 251       Treecko
# 327      Trapinch
# 519     Tranquill
# 453     Toxicroak
# 157      Totodile
# 388      Torterra
# 640      Tornadus
# 323       Torkoal
# 254       Torchic
# 175       Togetic
# 174        Togepi
# 467      Togekiss
# 563      Tirtouga
# 531       Timburr
# 641     Thundurus
# 537         Throh
# 638     Terrakion
# 497         Tepig
# 72     Tentacruel
# 71      Tentacool
# 215     Teddiursa
# 127        Tauros
# 464     Tangrowth
# 113       Tangela
# 662    Talonflame
# ...

# %%
pokemon[50:101]
# Out:
# 415     Vespiquen
# 2        Venusaur
# 47        Venonat
# 48       Venomoth
# 542      Venipede
# 133      Vaporeon
# 583     Vanilluxe
# 581     Vanillite
# 582     Vanillish
# 479          Uxie
# 216      Ursaring
# 200         Unown
# 520      Unfezant
# 196       Umbreon
# 695        Tyrunt
# 235       Tyrogue
# 696     Tyrantrum
# 247     Tyranitar
# 156    Typhlosion
# 601        Tynamo
# 534       Tympole
# 386       Turtwig
# 567      Trubbish
# 356       Tropius
# 708     Trevenant
# 251       Treecko
# 327      Trapinch
# 519     Tranquill
# 453     Toxicroak
# 157      Totodile
# 388      Torterra
# 640      Tornadus
# 323       Torkoal
# 254       Torchic
# 175       Togetic
# 174        Togepi
# 467      Togekiss
# 563      Tirtouga
# 531       Timburr
# 641     Thundurus
# 537         Throh
# 638     Terrakion
# 497         Tepig
# 72     Tentacruel
# 71      Tentacool
# 215     Teddiursa
# 127        Tauros
# 464     Tangrowth
# 113       Tangela
# 662    Talonflame
# ...

# %%
pokemon = pokemon.sort_index()

# %%
pokemon
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28        Nidoran
# 29       Nidorina
#           ...
# 691     Clauncher
# 692     Clawitzer
# 693    Helioptile
# 694     Heliolisk
# 695        Tyrunt
# 696     Tyrantrum
# 697        Amaura
# 698       Aurorus
# 699       Sylveon
# 700      Hawlucha
# 701       Dedenne
# 702       Carbink
# 703         Goomy
# 704       Sliggoo
# 705        Goodra
# 706        Klefki
# 707      Phantump
# 708     Trevenant
# 709     Pumpkaboo
# ...

# %%
pokemon[50:101]
# Out:
# 50        Dugtrio
# 51         Meowth
# 52        Persian
# 53        Psyduck
# 54        Golduck
# 55         Mankey
# 56       Primeape
# 57      Growlithe
# 58       Arcanine
# 59        Poliwag
# 60      Poliwhirl
# 61      Poliwrath
# 62           Abra
# 63        Kadabra
# 64       Alakazam
# 65         Machop
# 66        Machoke
# 67        Machamp
# 68     Bellsprout
# 69     Weepinbell
# 70     Victreebel
# 71      Tentacool
# 72     Tentacruel
# 73        Geodude
# 74       Graveler
# 75          Golem
# 76         Ponyta
# 77       Rapidash
# 78       Slowpoke
# 79        Slowbro
# 80      Magnemite
# 81       Magneton
# 82     Farfetch'd
# 83          Doduo
# 84         Dodrio
# 85           Seel
# 86        Dewgong
# 87         Grimer
# 88            Muk
# 89       Shellder
# 90       Cloyster
# 91         Gastly
# 92        Haunter
# 93         Gengar
# 94           Onix
# 95        Drowzee
# 96          Hypno
# 97         Krabby
# 98        Kingler
# 99        Voltorb
# ...

# %%
pokemon[:50]
# Out:
# 0      Bulbasaur
# 1        Ivysaur
# 2       Venusaur
# 3     Charmander
# 4     Charmeleon
# 5      Charizard
# 6       Squirtle
# 7      Wartortle
# 8      Blastoise
# 9       Caterpie
# 10       Metapod
# 11    Butterfree
# 12        Weedle
# 13        Kakuna
# 14      Beedrill
# 15        Pidgey
# 16     Pidgeotto
# 17       Pidgeot
# 18       Rattata
# 19      Raticate
# 20       Spearow
# 21        Fearow
# 22         Ekans
# 23         Arbok
# 24       Pikachu
# 25        Raichu
# 26     Sandshrew
# 27     Sandslash
# 28       Nidoran
# 29      Nidorina
# 30     Nidoqueen
# 31      Nidoran♂
# 32      Nidorino
# 33      Nidoking
# 34      Clefairy
# 35      Clefable
# 36        Vulpix
# 37     Ninetales
# 38    Jigglypuff
# 39    Wigglytuff
# 40         Zubat
# 41        Golbat
# 42        Oddish
# 43         Gloom
# 44     Vileplume
# 45         Paras
# 46      Parasect
# 47       Venonat
# 48      Venomoth
# 49       Diglett
# Name: Tee's Pokemon, dtype: object

# %%
pokemon[-31:-10:2]
# Out:
# 690     Dragalge
# 692    Clawitzer
# 694    Heliolisk
# 696    Tyrantrum
# 698      Aurorus
# 700     Hawlucha
# 702      Carbink
# 704      Sliggoo
# 706       Klefki
# 708    Trevenant
# 710    Gourgeist
# Name: Tee's Pokemon, dtype: object

# %%
pokemon
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28        Nidoran
# 29       Nidorina
#           ...
# 691     Clauncher
# 692     Clawitzer
# 693    Helioptile
# 694     Heliolisk
# 695        Tyrunt
# 696     Tyrantrum
# 697        Amaura
# 698       Aurorus
# 699       Sylveon
# 700      Hawlucha
# 701       Dedenne
# 702       Carbink
# 703         Goomy
# 704       Sliggoo
# 705        Goodra
# 706        Klefki
# 707      Phantump
# 708     Trevenant
# 709     Pumpkaboo
# ...

# %%
pokemon = pd.read_csv("pokemon.csv", index_col = "Pokemon", squeeze = True)

# %%
pokemon.head()
# Out:
# Pokemon
# Bulbasaur     Grass
# Ivysaur       Grass
# Venusaur      Grass
# Charmander     Fire
# Charmeleon     Fire
# Name: Type, dtype: object

# %%
pokemon[0]
# Out:
# 'Grass'

# %%
pokemon[[100, 134]]
# Out:
# Pokemon
# Electrode    Electric
# Jolteon      Electric
# Name: Type, dtype: object

# %%
pokemon['Pikachu']
# Out:
# 'Electric'

# %%
pokemon['Ditto']
# Out:
# 'Normal'

# %%
pokemon[["Unown", "Ditto"]]
# Out:
# Pokemon
# Unown    Psychic
# Ditto     Normal
# Name: Type, dtype: object

# %%
pokemon.get(['Moltres', 'Machop'])
# Out:
# Pokemon
# Moltres        Fire
# Machop     Fighting
# Name: Type, dtype: object

# %%
prices.head()
# Out:
# 11    49.95
# 9     50.07
# 0     50.12
# 10    50.70
# 12    50.74
# Name: Stock Price, dtype: float64

# %%
prices = prices.sort_index()

# %%
prices.head()
# Out:
# 0    50.12
# 1    54.10
# 2    54.65
# 3    52.38
# 4    52.95
# Name: Stock Price, dtype: float64

# %%
prices.count()
# Out:
# 3012

# %%
len(prices)
# Out:
# 3012

# %%
prices.describe()
# Out:
# count    3012.000000
# mean      334.310093
# std       173.187205
# min        49.950000
# 25%       218.045000
# 50%       283.315000
# 75%       443.000000
# max       782.220000
# Name: Stock Price, dtype: float64

# %%
prices.idxmax()
# Out:
# 3011

# %%
prices[3011]
# Out:
# 782.22000000000003

# %%
prices[prices.idxmin()]
# Out:
# 49.950000000000003

# %%
pokemon.head()
# Out:
# Pokemon
# Bulbasaur     Grass
# Ivysaur       Grass
# Venusaur      Grass
# Charmander     Fire
# Charmeleon     Fire
# Name: Type, dtype: object

# %%
pokemon.value_counts()
# Out:
# Water       105
# Normal       93
# Grass        66
# Bug          63
# Fire         47
# Psychic      47
# Rock         41
# Electric     36
# Ground       30
# Dark         28
# Poison       28
# Fighting     25
# Dragon       24
# Ice          23
# Ghost        23
# Steel        22
# Fairy        17
# Flying        3
# Name: Type, dtype: int64

# %%
prices.head(6)
# Out:
# 0    50.12
# 1    54.10
# 2    54.65
# 3    52.38
# 4    52.95
# 5    53.90
# Name: Stock Price, dtype: float64

# %%
def classify_performance(number):
    if number < 300:
        return "OK"
    elif number >= 300 and number < 650:
        return "Satisfactory"
    else:
        return "Incredible"

# %%
prices.apply(classify_performance)
# Out:
# 0               OK
# 1               OK
# 2               OK
# 3               OK
# 4               OK
# 5               OK
# 6               OK
# 7               OK
# 8               OK
# 9               OK
# 10              OK
# 11              OK
# 12              OK
# 13              OK
# 14              OK
# 15              OK
# 16              OK
# 17              OK
# 18              OK
# 19              OK
# 20              OK
# 21              OK
# 22              OK
# 23              OK
# 24              OK
# 25              OK
# 26              OK
# 27              OK
# 28              OK
# 29              OK
#            ...
# 2982    Incredible
# 2983    Incredible
# 2984    Incredible
# 2985    Incredible
# 2986    Incredible
# 2987    Incredible
# 2988    Incredible
# 2989    Incredible
# 2990    Incredible
# 2991    Incredible
# 2992    Incredible
# 2993    Incredible
# 2994    Incredible
# 2995    Incredible
# 2996    Incredible
# 2997    Incredible
# ...

# %%
prices.head(6)
# Out:
# 0    50.12
# 1    54.10
# 2    54.65
# 3    52.38
# 4    52.95
# 5    53.90
# Name: Stock Price, dtype: float64

# %%
prices.apply(lambda x:x + .87)
# Out:
# 0        50.99
# 1        54.97
# 2        55.52
# 3        53.25
# 4        53.82
# 5        54.77
# 6        53.89
# 7        51.82
# 8        52.00
# 9        50.94
# 10       51.57
# 11       50.82
# 12       51.61
# 13       51.97
# 14       51.97
# 15       53.48
# 16       54.57
# 17       56.56
# 18       56.81
# 19       57.80
# 20       59.56
# 21       60.49
# 22       59.73
# 23       60.00
# 24       61.22
# 25       60.73
# 26       59.94
# 27       64.24
# 28       66.34
# 29       65.61
#          ...
# 2982    676.09
# 2983    669.13
# 2984    680.91
# 2985    684.98
# 2986    692.97
# 2987    700.08
# 2988    695.36
# 2989    698.64
# 2990    696.23
# 2991    706.50
# 2992    715.96
# 2993    721.51
# 2994    717.85
# 2995    721.82
# 2996    720.72
# 2997    734.65
# 2998    737.83
# 2999    742.06
# 3000    739.50
# 3001    743.61
# 3002    740.64
# 3003    739.29
# 3004    742.64
# 3005    746.78
# 3006    769.66
# 3007    773.75
# 3008    771.94
# ...

# %%
pokemon.head()
# Out:
# Pokemon
# Bulbasaur     Grass
# Ivysaur       Grass
# Venusaur      Grass
# Charmander     Fire
# Charmeleon     Fire
# Name: Type, dtype: object

# %%
pokemon_names = pd.read_csv("pokemon.csv", usecols = ["Pokemon"], squeeze = True)
pokemon_names.head(3)
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# 2     Venusaur
# Name: Pokemon, dtype: object

# %%
pokemon_types = pd.read_csv("pokemon.csv", index_col = "Pokemon", squeeze = True)
pokemon_types.head(3)
# Out:
# Pokemon
# Bulbasaur    Grass
# Ivysaur      Grass
# Venusaur     Grass
# Name: Type, dtype: object

# %%
pokemon_names.map(pokemon_types)
# Out:
# 0         Grass
# 1         Grass
# 2         Grass
# 3          Fire
# 4          Fire
# 5          Fire
# 6         Water
# 7         Water
# 8         Water
# 9           Bug
# 10          Bug
# 11          Bug
# 12          Bug
# 13          Bug
# 14          Bug
# 15       Normal
# 16       Normal
# 17       Normal
# 18       Normal
# 19       Normal
# 20       Normal
# 21       Normal
# 22       Poison
# 23       Poison
# 24     Electric
# 25     Electric
# 26       Ground
# 27       Ground
# 28       Poison
# 29       Poison
#          ...
# 691       Water
# 692       Water
# 693    Electric
# 694    Electric
# 695        Rock
# 696        Rock
# 697        Rock
# 698        Rock
# 699       Fairy
# 700    Fighting
# 701    Electric
# 702        Rock
# 703      Dragon
# 704      Dragon
# 705      Dragon
# 706       Steel
# 707       Ghost
# 708       Ghost
# 709       Ghost
# 710       Ghost
# 711         Ice
# 712         Ice
# 713      Flying
# 714      Flying
# ...

# %%
pokemon_names = pd.read_csv("pokemon.csv", usecols = ["Pokemon"], squeeze = True)
pokemon_types = pd.read_csv("pokemon.csv", index_col  = "Pokemon", squeeze = True).to_dict()

# %%
pokemon_names.head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Pokemon, dtype: object

# %%
pokemon_types
# Out:
# {'Abomasnow': 'Grass',
#  'Abra': 'Psychic',
#  'Absol': 'Dark',
#  'Accelgor': 'Bug',
#  'Aegislash': 'Steel',
#  'Aerodactyl': 'Rock',
#  'Aggron': 'Steel',
#  'Aipom': 'Normal',
#  'Alakazam': 'Psychic',
#  'Alomomola': 'Water',
#  'Altaria': 'Dragon',
#  'Amaura': 'Rock',
#  'Ambipom': 'Normal',
#  'Amoonguss': 'Grass',
#  'Ampharos': 'Electric',
#  'Anorith': 'Rock',
#  'Arbok': 'Poison',
#  'Arcanine': 'Fire',
#  'Arceus': 'Normal',
#  'Archen': 'Rock',
#  'Archeops': 'Rock',
#  'Ariados': 'Bug',
#  'Armaldo': 'Rock',
#  'Aromatisse': 'Fairy',
#  'Aron': 'Steel',
#  'Articuno': 'Ice',
#  'Audino': 'Normal',
#  'Aurorus': 'Rock',
#  'Avalugg': 'Ice',
#  'Axew': 'Dragon',
#  'Azelf': 'Psychic',
#  'Azumarill': 'Water',
#  'Azurill': 'Normal',
#  'Bagon': 'Dragon',
#  'Baltoy': 'Ground',
#  'Banette': 'Ghost',
#  'Barbaracle': 'Rock',
#  'Barboach': 'Water',
#  'Basculin': 'Water',
#  'Bastiodon': 'Rock',
#  'Bayleef': 'Grass',
#  'Beartic': 'Ice',
#  'Beautifly': 'Bug',
# ...

# %%
pokemon_types["Luxio"]
# Out:
# 'Electric'

# %%
pokemon_names.map(pokemon_types)
# Out:
# 0         Grass
# 1         Grass
# 2         Grass
# 3          Fire
# 4          Fire
# 5          Fire
# 6         Water
# 7         Water
# 8         Water
# 9           Bug
# 10          Bug
# 11          Bug
# 12          Bug
# 13          Bug
# 14          Bug
# 15       Normal
# 16       Normal
# 17       Normal
# 18       Normal
# 19       Normal
# 20       Normal
# 21       Normal
# 22       Poison
# 23       Poison
# 24     Electric
# 25     Electric
# 26       Ground
# 27       Ground
# 28       Poison
# 29       Poison
#          ...
# 691       Water
# 692       Water
# 693    Electric
# 694    Electric
# 695        Rock
# 696        Rock
# 697        Rock
# 698        Rock
# 699       Fairy
# 700    Fighting
# 701    Electric
# 702        Rock
# 703      Dragon
# 704      Dragon
# 705      Dragon
# 706       Steel
# 707       Ghost
# 708       Ghost
# 709       Ghost
# 710       Ghost
# 711         Ice
# 712         Ice
# 713      Flying
# 714      Flying
# ...

# %%
pd.read_csv("pokemon.csv")
# Out:
#         Pokemon      Type
# 0     Bulbasaur     Grass
# 1       Ivysaur     Grass
# 2      Venusaur     Grass
# 3    Charmander      Fire
# 4    Charmeleon      Fire
# 5     Charizard      Fire
# 6      Squirtle     Water
# 7     Wartortle     Water
# 8     Blastoise     Water
# 9      Caterpie       Bug
# 10      Metapod       Bug
# 11   Butterfree       Bug
# 12       Weedle       Bug
# 13       Kakuna       Bug
# 14     Beedrill       Bug
# 15       Pidgey    Normal
# 16    Pidgeotto    Normal
# 17      Pidgeot    Normal
# 18      Rattata    Normal
# 19     Raticate    Normal
# 20      Spearow    Normal
# 21       Fearow    Normal
# 22        Ekans    Poison
# 23        Arbok    Poison
# 24      Pikachu  Electric
# 25       Raichu  Electric
# 26    Sandshrew    Ground
# 27    Sandslash    Ground
# 28      Nidoran    Poison
# 29     Nidorina    Poison
# ..          ...       ...
# 691   Clauncher     Water
# 692   Clawitzer     Water
# 693  Helioptile  Electric
# ...
